# %%
import river
import pandas as pd

# %%
data_path = "../data/resource_events.csv"
df = pd.read_csv(data_path)

print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
# Out:
# Dataset shape: (454, 25)
# Columns: ['pid', 'comm', 'uid', 'gid', 'ppid', 'user_pid', 'user_ppid', 'cgroup_id', 'cgroup_name', 'user', 'cpu_ns', 'user_faults', 'kernel_faults', 'vm_mmap_bytes', 'vm_munmap_bytes', 'vm_brk_grow_bytes', 'vm_brk_shrink_bytes', 'bytes_written', 'bytes_read', 'isActive', 'wall_time_dt', 'wall_time_ms', 'container_id', 'container_image', 'container_labels_json']

# %%
feature_cols = [
    "cpu_ns",
    "user_faults",
    "kernel_faults",
    "vm_mmap_bytes",
    "vm_munmap_bytes",
    "vm_brk_grow_bytes",
    "vm_brk_shrink_bytes",
    "bytes_written",
    "bytes_read"
]

context_cols = [
    "pid",
    "comm",
    "user",
    "container_id",
    "container_image",
    "wall_time_ms"
]

# %%
X = df[feature_cols].copy()
context = df[context_cols].copy()

print("\nFeature matrix sample:")
display(X.head())

print("\nContext sample:")
display(context.head())
# Out:
# Feature matrix sample:
#      cpu_ns  user_faults  kernel_faults  vm_mmap_bytes  vm_munmap_bytes  \
# 0   3374785            0              0              0                0
# 1    899677           14              0              0                0
# 2         0            0              0              0                0
# 3  12700969            2              0              0                0
# 4   3758715           23              1              0                0
#
#    vm_brk_grow_bytes  vm_brk_shrink_bytes  bytes_written  bytes_read
# 0                  0                    0              0           0
# 1                  0                    0            498        2660
# 2                  0                    0              0           0
# 3                  0                    0              0           4
# 4                  0                    0          17126       14909
# Context sample:
#     pid             comm             user  \
# 0   237          chronyd              NaN
# 1  4226  containerd-shim             root
# 2  3806        buildkitd             root
# 3  4323  VM Periodic Tas  systemd-network
# 4  7710             main            aleyi
#
#                                         container_id  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  04242fd9b1ae2cf32adc297f0b79e8120c2833f0e4cfe5...
# 4                                                NaN
#
#                  container_image   wall_time_ms
# 0                            NaN  1757364894741
# 1                            NaN  1757364894741
# 2                            NaN  1757364894741
# 3  provectuslabs/kafka-ui:latest  1757364894741
# 4                            NaN  1757364894741

# %%
X = X.fillna(0)

# %%
records = []
for i, row in X.iterrows():
    record = row.to_dict()
    # Keep context attached
    records.append((record, context.iloc[i].to_dict()))

print("\nExample record with context:")
print(records[0])
# Out:
# Example record with context:
# ({'cpu_ns': 3374785, 'user_faults': 0, 'kernel_faults': 0, 'vm_mmap_bytes': 0, 'vm_munmap_bytes': 0, 'vm_brk_grow_bytes': 0, 'vm_brk_shrink_bytes': 0, 'bytes_written': 0, 'bytes_read': 0}, {'pid': 237, 'comm': 'chronyd', 'user': nan, 'container_id': nan, 'container_image': nan, 'wall_time_ms': 1757364894741})

# %%
from river import compose, preprocessing, anomaly
import numpy as np

# %%
model = compose.Pipeline(
    preprocessing.MinMaxScaler(),
    anomaly.HalfSpaceTrees(
        n_trees=25,
        height=8,
        window_size=250,
        seed=42
    )
)

scores = []

for features, meta in records:
    score = model.score_one(features)  # anomaly score
    model.learn_one(features)          # update model
    
    record_out = {**meta, **features, "anomaly_score": score}
    scores.append(record_out)

# %%
results = pd.DataFrame(scores)
mean_score = results["anomaly_score"].mean()
std_score = results["anomaly_score"].std()
min_score = results["anomaly_score"].min()
max_score = results["anomaly_score"].max()

q95 = np.percentile(results["anomaly_score"], 95)
q99 = np.percentile(results["anomaly_score"], 99)

rate_q95 = (results["anomaly_score"] > q95).mean()
rate_q99 = (results["anomaly_score"] > q99).mean()

print("📊 Anomaly Score Metrics")
print(f"Mean: {mean_score:.4f}, Std: {std_score:.4f}")
print(f"Min: {min_score:.4f}, Max: {max_score:.4f}")
print(f"95th percentile: {q95:.4f} → anomaly rate ~ {rate_q95*100:.2f}%")
print(f"99th percentile: {q99:.4f} → anomaly rate ~ {rate_q99*100:.2f}%")
# Out:
# 📊 Anomaly Score Metrics
# Mean: 0.0682, Std: 0.1190
# Min: 0.0000, Max: 0.9680
# 95th percentile: 0.1726 → anomaly rate ~ 4.85%
# 99th percentile: 0.6755 → anomaly rate ~ 1.10%

# %%
top_anomalies = results.sort_values("anomaly_score", ascending=False).head(10)
display(top_anomalies)
# Out:
#       pid             comm             user  \
# 449  4145       ThreadPool  systemd-resolve
# 396  4145       ThreadPool  systemd-resolve
# 290  4145       ThreadPool  systemd-resolve
# 343  4145       ThreadPool  systemd-resolve
# 326  3343          dockerd             root
# 274  3343          dockerd             root
# 289  3145             init             root
# 327  4143  client-metrics-            aleyi
# 433  4143  client-metrics-            aleyi
# 275  4143  client-metrics-            aleyi
#
#                                           container_id  \
# 449  43ec67b6e84c43b3ef18e9bae1a5bcc5a53a9d8189a9f4...
# 396  43ec67b6e84c43b3ef18e9bae1a5bcc5a53a9d8189a9f4...
# 290  43ec67b6e84c43b3ef18e9bae1a5bcc5a53a9d8189a9f4...
# 343  43ec67b6e84c43b3ef18e9bae1a5bcc5a53a9d8189a9f4...
# 326                                                NaN
# 274                                                NaN
# 289                                                NaN
# 327  a1df103d039148efb25fc00f7cff04203adcf7c0849240...
# 433  a1df103d039148efb25fc00f7cff04203adcf7c0849240...
# 275  a1df103d039148efb25fc00f7cff04203adcf7c0849240...
#
#                          container_image   wall_time_ms     cpu_ns  \
# 449  clickhouse/clickhouse-server:latest  1757364874742  348349489
# 396  clickhouse/clickhouse-server:latest  1757364864718  325719769
# 290  clickhouse/clickhouse-server:latest  1757364844725  353755936
# 343  clickhouse/clickhouse-server:latest  1757364854727  368097514
# 326                                  NaN  1757364854727   18194130
# 274                                  NaN  1757364844724   15963104
# 289                                  NaN  1757364844725   34101546
# 327                  apache/kafka:latest  1757364854727  148282893
# 433                  apache/kafka:latest  1757364874742  140733148
# 275                  apache/kafka:latest  1757364844724  155888882
#
#      user_faults  kernel_faults  vm_mmap_bytes  vm_munmap_bytes  \
# 449        18452              5       47185920                0
# 396         8720              5        8388608                0
# 290         5125              3       31457280                0
# 343         4861              7       15204352                0
# 326           38              0              0                0
# 274          246              0              0                0
# 289            4              0              0                0
# 327         3184              0       18559120         16670720
# 433          924              0        4730880          4685824
# 275         2062              0        9843152          8306688
#
#      vm_brk_grow_bytes  vm_brk_shrink_bytes  bytes_written  bytes_read  \
# 449                  0                    0         674030      183123
# 396                  0                    0         576286      174232
# 290                  0                    0         297237      176937
# 343                  0                    0         328007      174000
# 326                  0                    0         133389     2784570
# 274                  0                    0          95060      394547
# 289                  0                    0         280114      269508
# 327                  0                    0          11529       15608
# 433                  0                    0          11915       10668
# 275                  0                    0          11207       10233
#
#      anomaly_score
# 449       0.968013
# 396       0.954100
# 290       0.869841
# 343       0.863321
# 326       0.721252
# 274       0.634856
# 289       0.550442
# 327       0.474294
# 433       0.474294
# 275       0.474294
