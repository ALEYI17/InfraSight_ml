# %%
import pandas as pd
df = pd.read_parquet("https://github.com/ALEYI17/gpu_test_infrasight/raw/refs/heads/main/dataset/final_gpu_event_tokens.parquet")
df.groupby(["app_name", "label"]).size()
display(df)
# Out:
#            pid     comm  uid  gid  ppid  user_pid  user_ppid  cgroup_id  \
# 0        21158  hashcat    0    0     0         0          0          0
# 1        21158  hashcat    0    0     0         0          0          0
# 2        21158  hashcat    0    0     0         0          0          0
# 3        21158  hashcat    0    0     0         0          0          0
# 4        21158  hashcat    0    0     0         0          0          0
# ...        ...      ...  ...  ...   ...       ...        ...        ...
# 5802995  23794  python3    0    0     0         0          0          0
# 5802996  23794  python3    0    0     0         0          0          0
# 5802997  23794  python3    0    0     0         0          0          0
# 5802998  23794  python3    0    0     0         0          0          0
# 5802999  23794  python3    0    0     0         0          0          0
#
#         cgroup_name user  ...     value dir                     wall_time_dt  \
# ...
